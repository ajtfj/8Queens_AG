# %%
from eightQueens_v1 import EightQueens, run, find_all
import numpy as np
import matplotlib.pyplot as plt

# %%
eightQueens = EightQueens()
convergedCount = 0
runEvaluation = []
runFitness = []

for i in range(30):
    totalConverged, evaluation, best_fitness_history, average_fitness_history = run(eightQueens)
    averageFitness = average_fitness_history[-1]
    
    find_all_evaluations = find_all(eightQueens)

    print(f"{i+1}ª execução:")
    print(f"    Número de indivíduos que convergiram foi {totalConverged}.")
    print(f"    Fitness médio: {averageFitness}.")
    print(f"    Foram necessárias {find_all_evaluations} avaliações para todos convergirem.\n")
    
    plt.plot(np.array(best_fitness_history), label="Best Fitness")
    plt.plot(np.array(average_fitness_history), label="Average Fitness")
    plt.legend()
    plt.show()

    if totalConverged > 0:
        convergedCount += 1
    
    runEvaluation.append(evaluation)
    runFitness.append(averageFitness)

print(f"O algoritimo convergiu em {convergedCount} execuções.")

mean = np.mean(runEvaluation)
std = np.std(runEvaluation)
print(f"Média de interações em que o algoritimo convergiu: {mean}. Desvio padrão: {std}.")

mean = np.mean(runFitness)
std = np.std(runFitness)
print(f"Média de fitness médio alcançado nas 30 execuções: {mean}. Desvio padrão: {std}.")
# Out:
# 1ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.30083333333333334.
#     Foram necessárias 195 avaliações para todos convergirem.
# 2ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.42.
#     Foram necessárias 283 avaliações para todos convergirem.
# 3ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.2998333333333333.
#     Foram necessárias 210 avaliações para todos convergirem.
# 4ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.27166666666666667.
#     Foram necessárias 328 avaliações para todos convergirem.
# 5ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.20245006790595022.
#     Foram necessárias 196 avaliações para todos convergirem.
# 6ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.2581666666666667.
#     Foram necessárias 321 avaliações para todos convergirem.
# 7ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.45.
#     Foram necessárias 207 avaliações para todos convergirem.
# 8ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.2538333333333334.
#     Foram necessárias 199 avaliações para todos convergirem.
# 9ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.35416666666666674.
#     Foram necessárias 259 avaliações para todos convergirem.
# 10ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.20169083694083695.
#     Foram necessárias 210 avaliações para todos convergirem.
# 11ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.4966666666666667.
#     Foram necessárias 239 avaliações para todos convergirem.
# 12ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.505.
#     Foram necessárias 275 avaliações para todos convergirem.
# 13ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.3341666666666667.
#     Foram necessárias 296 avaliações para todos convergirem.
# 14ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.2875.
#     Foram necessárias 254 avaliações para todos convergirem.
# 15ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.2488333333333334.
#     Foram necessárias 251 avaliações para todos convergirem.
# 16ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.4016666666666667.
#     Foram necessárias 206 avaliações para todos convergirem.
# 17ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.505.
#     Foram necessárias 228 avaliações para todos convergirem.
# 18ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.20906324231324228.
#     Foram necessárias 335 avaliações para todos convergirem.
# 19ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.1940277777777778.
#     Foram necessárias 315 avaliações para todos convergirem.
# 20ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.505.
#     Foram necessárias 259 avaliações para todos convergirem.
# 21ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.20934163059163058.
#     Foram necessárias 239 avaliações para todos convergirem.
# 22ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.31933333333333336.
#     Foram necessárias 317 avaliações para todos convergirem.
# 23ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.43833333333333335.
#     Foram necessárias 227 avaliações para todos convergirem.
# 24ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.19773881673881671.
#     Foram necessárias 238 avaliações para todos convergirem.
# 25ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.3975.
#     Foram necessárias 217 avaliações para todos convergirem.
# 26ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.505.
#     Foram necessárias 283 avaliações para todos convergirem.
# 27ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.505.
#     Foram necessárias 312 avaliações para todos convergirem.
# 28ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.2339999999999999.
#     Foram necessárias 302 avaliações para todos convergirem.
# 29ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.25900000000000006.
#     Foram necessárias 248 avaliações para todos convergirem.
# 30ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.2681666666666667.
#     Foram necessárias 282 avaliações para todos convergirem.
# O algoritimo convergiu em 30 execuções.
# Média de interações em que o algoritimo convergiu: 128.53333333333333. Desvio padrão: 224.2673602843019.
# Média de fitness médio alcançado nas 30 execuções: 0.3344326346311642. Desvio padrão: 0.11037124183638178.
