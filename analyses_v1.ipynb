# %%
from eightQueens_v1 import EightQueens, find_solution, converge_all
import numpy as np
import matplotlib.pyplot as plt

# %%
eightQueens = EightQueens()
convergedCount = 0
runEvaluation = []
runFitness = []

for i in range(30):
    totalConverged, evaluation, best_fitness_history, average_fitness_history = find_solution(eightQueens)
    averageFitness = average_fitness_history[-1]
    

    print(f"{i+1}ª execução:")
    print(f"    Número de indivíduos que convergiram foi {totalConverged}.")
    print(f"    Fitness médio: {averageFitness}.")
    
    plt.plot(np.array(best_fitness_history), label="Best Fitness")
    plt.plot(np.array(average_fitness_history), label="Average Fitness")
    plt.legend()
    plt.title("Convergência do primeiro indivíduo")
    plt.show()

    if totalConverged > 0:
        convergedCount += 1
    
    runEvaluation.append(evaluation)
    runFitness.append(averageFitness)

    evaluation, best_fitness_history, average_fitness_history = converge_all(eightQueens, evaluation, best_fitness_history, average_fitness_history)

    print(f"    Foram necessárias {evaluation} avaliações para todos convergirem.\n")

    plt.plot(np.array(best_fitness_history), label="Best Fitness")
    plt.plot(np.array(average_fitness_history), label="Average Fitness")
    plt.legend()
    plt.title("Convergência de todos os indivíduos")
    plt.show()

print(f"O algoritimo convergiu em {convergedCount} execuções.")

mean = np.mean(runEvaluation)
std = np.std(runEvaluation)
print(f"Média de interações em que o algoritimo convergiu: {mean}. Desvio padrão: {std}.")

mean = np.mean(runFitness)
std = np.std(runFitness)
print(f"Média de fitness médio alcançado nas 30 execuções: {mean}. Desvio padrão: {std}.")
# Out:
# 1ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.23342857142857143.
#     Foram necessárias 323 avaliações para todos convergirem.
# 2ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.40083333333333326.
#     Foram necessárias 300 avaliações para todos convergirem.
# 3ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.19063600288600285.
#     Foram necessárias 221 avaliações para todos convergirem.
# 4ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.3291666666666668.
#     Foram necessárias 288 avaliações para todos convergirem.
# 5ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.20409534909534904.
#     Foram necessárias 211 avaliações para todos convergirem.
# 6ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.2973333333333333.
#     Foram necessárias 376 avaliações para todos convergirem.
# 7ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.505.
#     Foram necessárias 522 avaliações para todos convergirem.
# 8ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.3038333333333333.
#     Foram necessárias 326 avaliações para todos convergirem.
# 9ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.505.
#     Foram necessárias 743 avaliações para todos convergirem.
# 10ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.19710786435786432.
#     Foram necessárias 266 avaliações para todos convergirem.
# 11ª execução:
#     Número de indivíduos que convergiram foi 3.
#     Fitness médio: 0.2128449883449883.
#     Foram necessárias 219 avaliações para todos convergirem.
# 12ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.20685425685425676.
#     Foram necessárias 233 avaliações para todos convergirem.
# 13ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.37333333333333335.
#     Foram necessárias 398 avaliações para todos convergirem.
# 14ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.20091677766677762.
#     Foram necessárias 319 avaliações para todos convergirem.
# 15ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.48833333333333345.
#     Foram necessárias 351 avaliações para todos convergirem.
# 16ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.505.
#     Foram necessárias 1009 avaliações para todos convergirem.
# 17ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.4633333333333334.
#     Foram necessárias 356 avaliações para todos convergirem.
# 18ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.26200000000000007.
#     Foram necessárias 189 avaliações para todos convergirem.
# 19ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.34083333333333343.
#     Foram necessárias 228 avaliações para todos convergirem.
# 20ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.3625.
#     Foram necessárias 255 avaliações para todos convergirem.
# 21ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.315.
#     Foram necessárias 237 avaliações para todos convergirem.
# 22ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.24533333333333338.
#     Foram necessárias 299 avaliações para todos convergirem.
# 23ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.2468333333333334.
#     Foram necessárias 229 avaliações para todos convergirem.
# 24ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.19108639971139968.
#     Foram necessárias 278 avaliações para todos convergirem.
# 25ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.20472256398572186.
#     Foram necessárias 257 avaliações para todos convergirem.
# 26ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.25433333333333336.
#     Foram necessárias 162 avaliações para todos convergirem.
# 27ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.39000000000000007.
#     Foram necessárias 429 avaliações para todos convergirem.
# 28ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.2816666666666666.
#     Foram necessárias 313 avaliações para todos convergirem.
# 29ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.42333333333333334.
#     Foram necessárias 311 avaliações para todos convergirem.
# 30ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.505.
#     Foram necessárias 546 avaliações para todos convergirem.
# O algoritimo convergiu em 30 execuções.
# Média de interações em que o algoritimo convergiu: 104.93333333333334. Desvio padrão: 148.46636730998108.
# Média de fitness médio alcançado nas 30 execuções: 0.3213230924776978. Desvio padrão: 0.10878439759670054.
