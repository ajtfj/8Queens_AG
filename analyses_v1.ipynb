# %%
from eightQueens_v1 import EightQueens, find_solution, converge_all
import numpy as np
import matplotlib.pyplot as plt

# %%
eightQueens = EightQueens()
convergedCount = 0
runEvaluation = []
runFitness = []

for i in range(30):
    totalConverged, evaluation, best_fitness_history, average_fitness_history = find_solution(eightQueens)
    averageFitness = average_fitness_history[-1]
    

    print(f"{i+1}ª execução:")
    print(f"    Número de indivíduos que convergiram foi {totalConverged}.")
    print(f"    Fitness médio: {averageFitness}.")
    
    plt.plot(np.array(best_fitness_history), label="Best Fitness")
    plt.plot(np.array(average_fitness_history), label="Average Fitness")
    plt.legend()
    plt.title("Convergência do primeiro indivíduo")
    plt.show()

    if totalConverged > 0:
        convergedCount += 1
    
    runEvaluation.append(evaluation)
    runFitness.append(averageFitness)

    evaluation, best_fitness_history, average_fitness_history = converge_all(eightQueens, evaluation, best_fitness_history, average_fitness_history)

    print(f"    Foram necessárias {evaluation} avaliações para todos convergirem.\n")

    plt.plot(np.array(best_fitness_history), label="Best Fitness")
    plt.plot(np.array(average_fitness_history), label="Average Fitness")
    plt.legend()
    plt.title("Convergência de todos os indivíduos")
    plt.show()

print(f"O algoritimo convergiu em {convergedCount} execuções.")

mean = np.mean(runEvaluation)
std = np.std(runEvaluation)
print(f"Média de iterações em que o algoritimo convergiu: {mean}. Desvio padrão: {std}.")

mean = np.mean(runFitness)
std = np.std(runFitness)
print(f"Média de fitness médio alcançado nas 30 execuções: {mean}. Desvio padrão: {std}.")
# Out:
# 1ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.2059852092352092.
#     Foram necessárias 219 avaliações para todos convergirem.
# 2ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.30833333333333335.
#     Foram necessárias 285 avaliações para todos convergirem.
# 3ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.4099999999999999.
#     Foram necessárias 283 avaliações para todos convergirem.
# 4ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.19845042865631096.
#     Foram necessárias 155 avaliações para todos convergirem.
# 5ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.288.
#     Foram necessárias 416 avaliações para todos convergirem.
# 6ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.3186666666666666.
#     Foram necessárias 259 avaliações para todos convergirem.
# 7ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.2110046897546897.
#     Foram necessárias 276 avaliações para todos convergirem.
# 8ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.505.
#     Foram necessárias 1133 avaliações para todos convergirem.
# 9ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.20169022644022644.
#     Foram necessárias 247 avaliações para todos convergirem.
# 10ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.24661904761904757.
#     Foram necessárias 229 avaliações para todos convergirem.
# 11ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.42333333333333334.
#     Foram necessárias 377 avaliações para todos convergirem.
# 12ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.24188095238095236.
#     Foram necessárias 281 avaliações para todos convergirem.
# 13ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.19109163059163062.
#     Foram necessárias 245 avaliações para todos convergirem.
# 14ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.30516666666666664.
#     Foram necessárias 289 avaliações para todos convergirem.
# 15ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.425.
#     Foram necessárias 322 avaliações para todos convergirem.
# 16ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.22483333333333327.
#     Foram necessárias 257 avaliações para todos convergirem.
# 17ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.23980952380952375.
#     Foram necessárias 195 avaliações para todos convergirem.
# 18ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.23999999999999994.
#     Foram necessárias 244 avaliações para todos convergirem.
# 19ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.505.
#     Foram necessárias 516 avaliações para todos convergirem.
# 20ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.29366666666666663.
#     Foram necessárias 222 avaliações para todos convergirem.
# 21ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.3841666666666667.
#     Foram necessárias 311 avaliações para todos convergirem.
# 22ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.3275.
#     Foram necessárias 403 avaliações para todos convergirem.
# 23ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.28350000000000003.
#     Foram necessárias 241 avaliações para todos convergirem.
# 24ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.505.
#     Foram necessárias 693 avaliações para todos convergirem.
# 25ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.2076852453102453.
#     Foram necessárias 359 avaliações para todos convergirem.
# 26ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.43.
#     Foram necessárias 368 avaliações para todos convergirem.
# 27ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.27116666666666667.
#     Foram necessárias 404 avaliações para todos convergirem.
# 28ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.48833333333333345.
#     Foram necessárias 279 avaliações para todos convergirem.
# 29ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.3175.
#     Foram necessárias 319 avaliações para todos convergirem.
# 30ª execução:
#     Número de indivíduos que convergiram foi 1.
#     Fitness médio: 0.30333333333333334.
#     Foram necessárias 278 avaliações para todos convergirem.
# O algoritimo convergiu em 30 execuções.
# Média de iterações em que o algoritimo convergiu: 91.93333333333334. Desvio padrão: 142.46986425985747.
# Média de fitness médio alcançado nas 30 execuções: 0.3167238984599278. Desvio padrão: 0.0998497584023791.
